# %%
print("OK")
# Out:
# OK

# %% [markdown]
# mongodb+srv://arfin123:arfin123@cluster2.dopiv4y.mongodb.net/?appName=Cluster2

# %%
import pandas as pd

# %%
# %pwd
# Out:
# 'd:\\MLL-02\\End-to-End-Wine-Quality-Prediction\\notebooks'

# %%
df = pd.read_csv("winequality-red.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='str')

# %%
data = df.to_dict(orient='records')
data
# Out:
# [{'fixed acidity': 7.4,
#   'volatile acidity': 0.7,
#   'citric acid': 0.0,
#   'residual sugar': 1.9,
#   'chlorides': 0.076,
#   'free sulfur dioxide': 11.0,
#   'total sulfur dioxide': 34.0,
#   'density': 0.9978,
#   'pH': 3.51,
#   'sulphates': 0.56,
#   'alcohol': 9.4,
#   'quality': 5},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.88,
#   'citric acid': 0.0,
#   'residual sugar': 2.6,
#   'chlorides': 0.098,
#   'free sulfur dioxide': 25.0,
#   'total sulfur dioxide': 67.0,
#   'density': 0.9968,
#   'pH': 3.2,
#   'sulphates': 0.68,
#   'alcohol': 9.8,
#   'quality': 5},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.76,
#   'citric acid': 0.04,
#   'residual sugar': 2.3,
#   'chlorides': 0.092,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 54.0,
#   'density': 0.997,
#   'pH': 3.26,
#   'sulphates': 0.65,
#   'alcohol': 9.8,
#   'quality': 5},
#  {'fixed acidity': 11.2,
#   'volatile acidity': 0.28,
#   'citric acid': 0.56,
# ...

# %%
DB_NAME = "Wine_Quality_Prediction"
COLLECTION_NAME = "wine_data"
CONNECTION_URL = "mongodb+srv://arfin123:arfin123@cluster2.dopiv4y.mongodb.net/?appName=Cluster2"

# %%
import pandas as pd
from pymongo import MongoClient

# === STEP 1: Load your dataset ===
file_path = "winequality-red.csv"
df = pd.read_csv(file_path)

# Convert DataFrame to dictionary (records)
data = df.to_dict(orient="records")

# === STEP 2: Connect to MongoDB Atlas ===
# Replace with your actual connection string
MONGO_URI = "mongodb+srv://arfin123:arfin123@cluster2.dopiv4y.mongodb.net/?appName=Cluster2"

client = MongoClient(MONGO_URI)

# === STEP 3: Create / access database and collection ===
db = client["Wine_Quality_Prediction"]          # database name
collection = db["wine_data"]   # collection name

# === STEP 4: Insert data into MongoDB ===
collection.insert_many(data)

print("✅ Data successfully uploaded to MongoDB Atlas!")
# Out:
# ✅ Data successfully uploaded to MongoDB Atlas!

# %%
print(client.list_database_names())
# Out:
# ['Wine_Quality_Prediction', 'admin', 'local']

# %%
print(collection.count_documents({}))
print(collection.find_one())
# Out:
# 1599
# {'_id': ObjectId('6a1073330a6ca7c75455d4e9'), 'fixed acidity': 7.4, 'volatile acidity': 0.7, 'citric acid': 0.0, 'residual sugar': 1.9, 'chlorides': 0.076, 'free sulfur dioxide': 11.0, 'total sulfur dioxide': 34.0, 'density': 0.9978, 'pH': 3.51, 'sulphates': 0.56, 'alcohol': 9.4, 'quality': 5}

# %% [markdown]
# # Get Data

# %%
records = collection.find()

for i, record in enumerate(records):
    print(f"{i} : {record}")

# close AFTER loop (if needed)
# client.close()
# Out:
# 0 : {'_id': ObjectId('6a1073330a6ca7c75455d4e9'), 'fixed acidity': 7.4, 'volatile acidity': 0.7, 'citric acid': 0.0, 'residual sugar': 1.9, 'chlorides': 0.076, 'free sulfur dioxide': 11.0, 'total sulfur dioxide': 34.0, 'density': 0.9978, 'pH': 3.51, 'sulphates': 0.56, 'alcohol': 9.4, 'quality': 5}
# 1 : {'_id': ObjectId('6a1073330a6ca7c75455d4ea'), 'fixed acidity': 7.8, 'volatile acidity': 0.88, 'citric acid': 0.0, 'residual sugar': 2.6, 'chlorides': 0.098, 'free sulfur dioxide': 25.0, 'total sulfur dioxide': 67.0, 'density': 0.9968, 'pH': 3.2, 'sulphates': 0.68, 'alcohol': 9.8, 'quality': 5}
# 2 : {'_id': ObjectId('6a1073330a6ca7c75455d4eb'), 'fixed acidity': 7.8, 'volatile acidity': 0.76, 'citric acid': 0.04, 'residual sugar': 2.3, 'chlorides': 0.092, 'free sulfur dioxide': 15.0, 'total sulfur dioxide': 54.0, 'density': 0.997, 'pH': 3.26, 'sulphates': 0.65, 'alcohol': 9.8, 'quality': 5}
# ...

# %%
df = pd.DataFrame(list(collection.find()))

# %%
df.head()
# Out:
#                         _id  fixed acidity  volatile acidity  citric acid  \
# 0  6a1073330a6ca7c75455d4e9            7.4              0.70         0.00
# 1  6a1073330a6ca7c75455d4ea            7.8              0.88         0.00
# 2  6a1073330a6ca7c75455d4eb            7.8              0.76         0.04
# 3  6a1073330a6ca7c75455d4ec           11.2              0.28         0.56
# 4  6a1073330a6ca7c75455d4ed            7.4              0.70         0.00
#
#    residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0             1.9      0.076                 11.0                  34.0
# 1             2.6      0.098                 25.0                  67.0
# 2             2.3      0.092                 15.0                  54.0
# 3             1.9      0.075                 17.0                  60.0
# 4             1.9      0.076                 11.0                  34.0
#
#    density    pH  sulphates  alcohol  quality
# ...

# %%
if "_id" in df.columns.to_list():
    df.drop(columns=["_id"], inplace=True)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...
